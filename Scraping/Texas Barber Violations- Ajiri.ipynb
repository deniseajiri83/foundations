# %% [markdown]
# # Texas Barber Violations
#
# Texas has a system for [searching for license violations](https://www.tdlr.texas.gov/cimsfo/fosearch.asp). You're going to search for barbers in Houson!

# %% [markdown]
# ## Preparation: Knowing your tags
#
# These questions are the same for every data set, and might not work exactly for yours.

# %%
#look at the form tag. what's the name of the place we type outr search (it's an input tag)
#copy all the input tags, 
#in inspector go to network tab
#search with it open. do your search with this open (opr name...)
#1. open web inspector
#2. open network
#3. click the page that loaded (header tag)
#referer: which webpage did you come from?
#the one you want is "Form Data"
# curl downloads things in terminal
# XHR in the omspect -> network tab is JSON or talking to an API

#for H&M type you need to get the API. refresh the page, open the inspect, for to XHR and try to find the API
#in request url tab

#headers, checking for APIs in network tab

# %% [markdown]
# ### What is the tag and class name for every row of data?

# %%
#it's in "tr" tag, style ="background:#ffffff;"
#//*[@id="dat-menu"]/div/div[2]/div/div/section/div/div/table/tbody/tr[2]

# %% [markdown]
# ### What is the tag and class name for every person's name?

# %%
#It's in 'span' tag, class_= 'results_text'
#//*[@id="dat-menu"]/div/div[2]/div/div/section/div/div/table/tbody/tr[2]/td[1]/span[1]

# %% [markdown]
# ### What is the tag and class name for the violation number?

# %%
#It's in 'span' tag, class_= 'results_text'
#//*[@id="dat-menu"]/div/div[2]/div/div/section/div/div/table/tbody/tr[2]/td[1]/span[13]

# %% [markdown]
# ### What is the tag and class name for the description of their violation?

# %%
#It's in td, style="padding:4px; text-align:left; font-size:11px; font:"
#//*[@id="dat-menu"]/div/div[2]/div/div/section/div/div/table/tbody/tr[3]/td[3]

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# Use `requests`, not `urllib`.

# %% [markdown]
# import requests
# from bs4 import BeautifulSoup
# response = requests.post ("https://www.tdlr.texas.gov/cimsfo/fosearch_results.asp", data=data)

# %% [markdown]
# This is a curl command... making a request to the server... we are slowly take away headers to make our dic smaller. so get rid of -H one by one and run it in terminal and see if it works. if it doesn't skip it and go to the next -h
#
# curl 'https://www.tdlr.texas.gov/cimsfo/fosearch_results.asp' -H 'Referer: https://www.tdlr.texas.gov/cimsfo/fosearch.asp' --data 'pht_status=BAR&pht_lic=&pht_lnm=&pht_fnm=&pht_oth_name=&phy_city=HOUSTON+++++++++++++&phy_cnty=-1&phy_zip=&B1=Search' --compressed
#
# Everythings between h is the info
#
# -H 'Cookie: ASPSESSIONIDSGCTTRDT=MONJEPKCLOCBPJNJHPHLMNBO'
#
# -H 'Origin: https://www.tdlr.texas.gov' -H 'Accept-Encoding: gzip, deflate, br' -H 'Accept-Language: en-US,en;q=0.8,fa;q=0.6,tr;q=0.4' -H 'Upgrade-Insecure-Requests: 1' -H 'User-Agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36' -H 'Content-Type: application/x-www-form-urlencoded' -H 'Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8' -H 'Cache-Control: max-age=0'
# -H 'Connection: keep-alive'

# %% [markdown]
# Accept:text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8
# Accept-Encoding:gzip, deflate, br
# Accept-Language:en-US,en;q=0.8,fa;q=0.6,tr;q=0.4
# Cache-Control:max-age=0
# Connection:keep-alive
# Content-Length:116
# Content-Type:application/x-www-form-urlencoded
# Cookie:ASPSESSIONIDSGCTTRDT=MONJEPKCLOCBPJNJHPHLMNBO
# Host:www.tdlr.texas.gov
# Origin:https://www.tdlr.texas.gov
# Referer:https://www.tdlr.texas.gov/cimsfo/fosearch.asp
# Upgrade-Insecure-Requests:1
# User-Agent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36

# %% [markdown]
# headers = {
#     'Referer': 'https://www.tdlr.texas.gov/cimsfo/fosearch.asp',
#     'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
# }

# %% [markdown]
# ## Try to scrape the page
#
# To test if you requested the page correctly, save the BeautifulSoup document as `doc` and run the code `doc.find_all('tr')[1].text` to get the text of the first `<tr>` element.
#
# - If the result starts with  **nPlease enter at least one (1) parameter** you were NOT successful.
# - If the result starts with **MONTES DE OCA, REINIER**, you were successful.
#
# ### Try to request the page however you think you should.
#
# "Try" to do it, because it *will not work.* Once you've learned that it won't work, you should **ask how to do it on the board**.

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ### Try to request the page with the correct data parameters
#
# Secret tip: It still won't work. **Ask why not on the board.**

# %%
data = { "pht_status" : "BAR",
       "pht_lic": "",
       "pht_lnm" : "",
       "pht_fnm": "",
       "pht_oth_name" : "",
       "phy_city" : "HOUSTON",
       "phy_cnty" :"-1",
       "phy_zip" : "",
       "B1" : "Search"}

# %% [markdown]
# ### What is the smallest `curl` command that still gives you a result?

# %%
headers= {"Referer" : "https://www.tdlr.texas.gov/cimsfo/fosearch.asp"}
#headers = {
    #'Referer': 'https://www.tdlr.texas.gov/cimsfo/fosearch.asp',
    #'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
#}

# %% [markdown]
# ## Request the page with the correct data parameters AND the correct MINIMUM headers
#
# This time it should work.

# %%
response = requests.post ("https://www.tdlr.texas.gov/cimsfo/fosearch_results.asp", data=data, headers=headers)

doc = BeautifulSoup(response.text, "html.parser")

doc.prettify()
# Out:
# '<!DOCTYPE  >\n<html lang="en">\n <head>\n  <!-- Meta Tags -->\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>\n  <!-- Favicon -->\n  <link href="/images/favicon.png" rel="shortcut icon" type="image/x-icon"/>\n  <!-- Stylesheets -->\n  <link href="/css/reset.css" rel="stylesheet" type="text/css"/>\n  <link href="/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>\n  <link href="/css/animate.css" rel="stylesheet" type="text/css"/>\n  <link href="/css/main-stylesheet.css" rel="stylesheet" type="text/css"/>\n  <link href="/css/lightbox.css" rel="stylesheet" type="text/css"/>\n  <link href="/css/shortcodes.css" rel="stylesheet" type="text/css"/>\n  <link href="/css/custom-fonts.css" rel="stylesheet" type="text/css"/>\n  <link href="/css/custom-colors.css" rel="stylesheet" type="text/css"/>\n  <link href="/css/responsive.css" rel="stylesheet" type="text/css"/>\n  <li
# ...

# %% [markdown]
# ## Scraping

# %% [markdown]
# ### Loop through each `tr` and print each person's name
#
# You'll get an error because the first one doesn't have a name. How do you make that not happen? I'm happy to help if you ask on the board.

# %%
#I DID IT ALL AT THE END OF THE PAGE
rows=doc.find_all("tr", style="background:#ffffff;")

len(rows)
# Out:
# 88

# %%
rows += doc.find_all("tr", style="background:#dedede;") 

len(rows)
# Out:
# 175

# %% [markdown]
# ## Loop through each `tr`, printing each violation description
#
# - TIP: What is the container tag name for it?
# - TIP: You'll get an error even if you're ALMOST right - which row is causing the problem?

# %% [markdown]
# ## Loop through each `tr`, printing the complaint number
#
# - TIP: It should be the last piece of the fist `td`

# %%
for row in rows:
    tds = row.find_all('td')
    spans = tds[0].find_all("span", class_="results_text")
    name = spans[0]
    violation = spans[-1]
    describe = tds[2]
    print(name.text)
    if violation:
        print(violation.text)
    print(describe.text)
    print ("-------")
# Out:
# MONTES DE OCA, REINIER
# BAR20170009735
# Respondent performed barbering without the required license.
# -------
# CHAPMAN, JESSICA
# BAR20160014463
# Respondent failed to electronically submit to the Department at least one time per month student's accrued hours.
# -------
# GONZALES, DAVID
# BAR20160024898
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# -------
# ARMSTEAD, CEDRIC J
# BAR20170017750
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# -------
# TREJO, BLADIMAR A
# BAR20170015712
# Respondent performed barbering without the required license.
# -------
# HOPKINS, JOSHUA
# BAR20170004945
# Respondent performed barbering without the required license.
# -------
# HEATH, LOLETHA N
# BAR20170008862
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# -------
# ...

# %% [markdown]
# ## Saving the results
#
# ### Loop through each `tr` to create a list of dictionaries
#
# Each dictionary must contain
#
# - Person's name
# - Violation description
# - Violation number
#
# Create a new dictionary for each `tr` (except the header).

# %%
cases = []
for row in rows:
    current = {}
    tds = row.find_all('td')
    spans = tds[0].find_all("span", class_="results_text")
    name = spans[0]
    violation = spans[-1]
    describe = tds[2]
    current['name'] = name.text
    
    if violation:
        current['violation']=violation.text.rstrip()
    current['describe'] = describe.text
    cases.append(current)
print(cases)
# Out:
# [{'name': 'MONTES DE OCA, REINIER ', 'violation': 'BAR20170009735', 'describe': 'Respondent performed barbering without the required license.'}, {'name': 'CHAPMAN, JESSICA ', 'violation': 'BAR20160014463', 'describe': "Respondent failed to electronically submit to the Department at least one time per month student's accrued hours."}, {'name': 'GONZALES, DAVID ', 'violation': 'BAR20160024898', 'describe': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.'}, {'name': 'ARMSTEAD, CEDRIC J', 'violation': 'BAR20170017750', 'describe': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary."}, {'name': 'TREJO, BLADIMAR A', 'violation': 'BAR20170015712', 'describe': 'Respondent performed barbering without the required license.'}, {'name': 'HOPKINS, JOSHUA ', 'violation': 'BAR20170004945', 'describe': 'Respondent performed barbering without the required license.'}, {'name':
# ...

# %% [markdown]
# ### Save that to a CSV

# %%
import pandas as pd

#df.to_csv("stories.csv" , index = False)

# %%
df = pd.DataFrame(cases)
df.to_csv("cases.csv" , index = False)
df
# Out:
#                                               describe  \
# 0    Respondent performed barbering without the req...
# 1    Respondent failed to electronically submit to ...
# 2    Respondent leased space in a barber shop to an...
# 3    The Respondent's license was revoked upon Resp...
# 4    Respondent performed barbering without the req...
# 5    Respondent performed barbering without the req...
# 6    Respondent leased space in a barber shop to an...
# 7    Respondent performed barbering without the req...
# 8    Respondent performed barbering without the req...
# 9    The Respondent's license was revoked upon Resp...
# 10   Respondent performed barbering without the req...
# 11   Respondent performed barbering without the req...
# 12   Respondent leased space in a barber shop to an...
# 13   Respondent performed barbering without the req...
# 14   Respondent is ordered to immediately cease and...
# 15   The Respondent's license was revoked upon Resp...
# ...

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
df.head()
# Out:
#                                             describe                     name  \
# 0  Respondent performed barbering without the req...  MONTES DE OCA, REINIER
# 1  Respondent failed to electronically submit to ...        CHAPMAN, JESSICA
# 2  Respondent leased space in a barber shop to an...         GONZALES, DAVID
# 3  The Respondent's license was revoked upon Resp...       ARMSTEAD, CEDRIC J
# 4  Respondent performed barbering without the req...        TREJO, BLADIMAR A
#
#         violation
# 0  BAR20170009735
# 1  BAR20160014463
# 2  BAR20160024898
# 3  BAR20170017750
# 4  BAR20170015712
