# %% [markdown]
# # Introduction to Pandas

# %%
#when you shut down a jupyter and open it again
#you need to run your commands all over again.
#kernel: restart and run all or,
#cell: run all

# if on the top right it says connecting to kernel and it's slow and you see (*) next to your command line,
#just shutdown your jupyter (ctrl+c) in terminal and restart it again.

#your panda version : pd.__version__

import pandas as pd

# %%
pd.__version__
# Out:
# '0.20.2'

# %%
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python3.6/site-packages/pandas/__init__.py'>

# %%
#when you want to start pandas (just once) you need to open a new terminal (out of jupyter) and write either "pip install pandas' or "pip3 install pandas"

# %%
pd.read_csv("countries.csv")
# Out:
#                     Country   Continent  GDP_per_capita  life_expectancy  \
# 0               Afghanistan        Asia             663           54.863
# 1                   Albania      Europe            4195           74.200
# 2                   Algeria      Africa            5098           68.963
# 3                    Angola      Africa            2446           45.234
# 4       Antigua and Barbuda  N. America           12738           73.544
# 5                 Argentina  S. America           10571           73.822
# 6                   Armenia      Europe            2114           71.494
# 7                 Australia     Oceania           29241           79.930
# 8                   Austria      Europe           32008           78.330
# 9                Azerbaijan      Europe            2533           66.851
# 10                  Bahamas  N. America           22728           72.370
# 11                  Bahrain        Asia           22015           74.497
# ...

# %%
#df is a data frame.

df = pd.read_csv("countries.csv")

# %%
#first few rows
df.head(10)
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
# 5            Argentina  S. America           10571           73.822
# 6              Armenia      Europe            2114           71.494
# 7            Australia     Oceania           29241           79.930
# 8              Austria      Europe           32008           78.330
# 9           Azerbaijan      Europe            2533           66.851
#
#    Population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656
# 5    36930709
# 6     3076098
# 7    19164351
# 8     8004712
# 9     8110723

# %%
#las few rows
df.tail()
# Out:
#                 Country Continent  GDP_per_capita  life_expectancy  Population
# 183             Vietnam      Asia            1577           73.777    78758010
# 184  West Bank and Gaza      Asia            7586           70.929     3198560
# 185         Yemen, Rep.      Asia            2217           60.404    17723186
# 186              Zambia    Africa            1035           41.802    10201562
# 187            Zimbabwe    Africa             745           43.976    12509477

# %%
df.columns
# Out:
# Index(['Country', 'Continent', 'GDP_per_capita', 'life_expectancy',
#        'Population'],
#       dtype='object')

# %%
#objects means string
df.dtypes
# Out:
# Country             object
# Continent           object
# GDP_per_capita       int64
# life_expectancy    float64
# Population           int64
# dtype: object

# %%
#order by in SQL... in pandas

df.sort_values(by="Population")

#we need to sort it in a descending way.

#in SQL it is DESC. but in pandas we say do not go into ascending order

df.sort_values(by="Population" , ascending=False)

#if you have questions in pandas use ?: df.sort_values?
# Out:
#                               Country   Continent  GDP_per_capita  \
# 34                              China        Asia            3407
# 75                              India        Asia            1648
# 178                     United States  N. America           39758
# 76                          Indonesia        Asia            2714
# 22                             Brazil  S. America            8056
# 137                            Russia        Asia            8570
# 127                          Pakistan        Asia            2086
# 12                         Bangladesh        Asia            1075
# 83                              Japan        Asia           28559
# 124                           Nigeria      Africa            1619
# 110                            Mexico  N. America           10894
# 61                            Germany      Europe           29726
# 183                           Vietnam        Asia            1577
# ...

# %%
# True and False are BOOLEAN values
#true/false values, but they're special with a capital T or F

# %%
df["Population"]
#it's a list of dictionaries.
#One column called a series in pandas.
#index: 0,1,2,3 are
# Out:
# 0       22856302
# 1        3071856
# 2       30533827
# 3       13926373
# 4          77656
# 5       36930709
# 6        3076098
# 7       19164351
# 8        8004712
# 9        8110723
# 10        297651
# 11        638193
# 12     129592275
# 13        267511
# 14      10057810
# 15      10175684
# 16        250512
# 17       6517810
# 18        571262
# 19       8307248
# 20       3693698
# 21       1757925
# 22     174425387
# 23        327036
# 24       8006158
# 25      12294012
# 26       6374347
# 27      12446949
# 28      15678269
# 29      30667365
#          ...
# 158       466846
# 159      1063832
# 160      8860153
# 161      7167908
# 162     15988534
# 163     22183000
# 164      6172807
# 165     34038161
# 166     63155029
# 167       830089
# 168      4793504
# 169        97935
# 170      1292058
# 171      9456117
# 172     63627862
# 173      4501419
# 174     24213120
# 175     48891792
# 176      3033491
# 177     58874117
# 178    282496310
# ...

# %%
df["Population"].sum()
# Out:
# 6115042358

# %%
df["Population"].median()
# Out:
# 6888970.5

# %%
df["Population"].mean()
# Out:
# 32526821.05319149

# %%
df["Population"].std()
# Out:
# 123795162.37011255

# %%
df["Population"].max()
# Out:
# 1269116737

# %%
#this is too long to type.
#use describe and it'll give you a summary of all the above

# %%
df["Population"].describe()
# Out:
# count    1.880000e+02
# mean     3.252682e+07
# std      1.237952e+08
# min      5.619600e+04
# 25%      2.003170e+06
# 50%      6.888970e+06
# 75%      2.218517e+07
# max      1.269117e+09
# Name: Population, dtype: float64

# %%
#it looks ugly. convert all the numbers to integers to solve the problem.

df["Population"].describe().astype(int)
# Out:
# count           188
# mean       32526821
# std       123795162
# min           56196
# 25%         2003169
# 50%         6888970
# 75%        22185170
# max      1269116737
# Name: Population, dtype: int64

# %%
#now let's the continent column
df["Continent"]
# Out:
# 0            Asia
# 1          Europe
# 2          Africa
# 3          Africa
# 4      N. America
# 5      S. America
# 6          Europe
# 7         Oceania
# 8          Europe
# 9          Europe
# 10     N. America
# 11           Asia
# 12           Asia
# 13     N. America
# 14         Europe
# 15         Europe
# 16     N. America
# 17         Africa
# 18           Asia
# 19     S. America
# 20         Europe
# 21         Africa
# 22     S. America
# 23           Asia
# 24         Europe
# 25         Africa
# 26         Africa
# 27           Asia
# 28         Africa
# 29     N. America
#           ...
# 158    S. America
# 159        Africa
# 160        Europe
# 161        Europe
# 162          Asia
# 163          Asia
# 164          Asia
# 165        Africa
# 166          Asia
# 167          Asia
# 168        Africa
# 169       Oceania
# 170    N. America
# 171        Africa
# 172          Asia
# 173          Asia
# 174        Africa
# 175        Europe
# 176          Asia
# ...

# %%
#if you want to know stuff about a non-numeric column
df["Continent"].value_counts()
# Out:
# Africa        54
# Asia          48
# Europe        42
# N. America    22
# S. America    12
# Oceania       10
# Name: Continent, dtype: int64

# %%
# you can also describe but it isn't as good as string columns (the one we did above)
df["Continent"].describe()
# Out:
# count        188
# unique         6
# top       Africa
# freq          54
# Name: Continent, dtype: object

# %%
#let's make charts
#df["Continent"].value_counts().plot
#<pandas.plotting._core.SeriesPlotMethods object at 0x10a968f28>... 
#if you get this, it means you forgot to do something else. It's not all wrong, tweak it.

# %%
# matplotlib (%) is a magic. it says jupyter change the way you do stuff
# we use this MAGIC jupyter line in order
#to ask jupyter to do things differently

#pip install marplotlib

# %matplotlib inline

# %%
df["Continent"].value_counts().plot()

# %%
df["Continent"].value_counts().plot(kind='bar')

# %%
df["Continent"].value_counts().plot(kind='barh')

# %%
df["Continent"].value_counts().plot(kind='pie')

# %%
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
# scatter plots
df.plot(kind="scatter", x="GDP_per_capita", y="life_expectancy")

# %%
#to explore, have a hypothesis, ask your data a relevant question (command).

# %%
#pivot tables in csv: Group by in SQL and Pandas

#what column to group by
df.groupby("Continent")

# %%
#what column we want information about
df.groupby("Continent")["GDP_per_capita"]

# %%
#And what kind of information we want about that column
df.groupby("Continent")["GDP_per_capita"].mean()
# Out:
# Continent
# Africa         2621.648148
# Asia          11106.437500
# Europe        18647.880952
# N. America    11665.681818
# Oceania        8038.400000
# S. America     6738.583333
# Name: GDP_per_capita, dtype: float64

# %%
#when you do an action use pranthesis. when you want to specify what you want you use bracets []
#df.groupby("Continent")["GDP_per_capita"]

# %%
#when we have a huge dataset, maybe we should look at part of it

# %%
#this gives you the number of rows and columns
df.shape
# Out:
# (188, 5)

# %%
#how do you say: is your continent Asia
#if you run something before, it might affect your command
#run all the cells again
df["Continent"] == "Asia"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12      True
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18      True
# 19     False
# 20     False
# 21     False
# 22     False
# 23      True
# 24     False
# 25     False
# 26     False
# 27      True
# 28     False
# 29     False
#        ...
# 158    False
# 159    False
# 160    False
# 161    False
# 162     True
# 163     True
# 164     True
# 165    False
# 166     True
# 167     True
# 168    False
# 169    False
# 170    False
# 171    False
# 172     True
# 173     True
# 174    False
# 175    False
# 176     True
# 177    False
# 178    False
# 179    False
# 180     True
# 181    False
# 182    False
# 183     True
# 184     True
# 185     True
# 186    False
# 187    False
# Name: Continent, Length: 188, dtype: bool

# %%
#df[ ] on outside
# and your comparison on the inside
df[df["Continent"] == "Asia"]
# Out:
#                   Country Continent  GDP_per_capita  life_expectancy  \
# 0             Afghanistan      Asia             663           54.863
# 11                Bahrain      Asia           22015           74.497
# 12             Bangladesh      Asia            1075           65.309
# 18                 Bhutan      Asia            2922           60.307
# 23                 Brunei      Asia           48020           75.927
# 27               Cambodia      Asia             982           62.030
# 34                  China      Asia            3407           72.124
# 72       Hong Kong, China      Asia           29972           80.361
# 75                  India      Asia            1648           62.129
# 76              Indonesia      Asia            2714           67.289
# 77                   Iran      Asia            8600           69.611
# 78                   Iraq      Asia            3951           70.845
# 80                 Israel      Asia           22834           78.750
# ...

# %%
#1.df['GDP_per_capita'].mean()
#2.df['GDP_per_capita'] > df['GDP_per_capita'].mean()

# %%
#3
df[df['GDP_per_capita'] > df['GDP_per_capita'].mean()]

#you will put a lot of square brackets on your codes.
#be ready for it. You can also redefine new variables, but it's not that much better
# Out:
#                   Country   Continent  GDP_per_capita  life_expectancy  \
# 4     Antigua and Barbuda  N. America           12738        73.544000
# 5               Argentina  S. America           10571        73.822000
# 7               Australia     Oceania           29241        79.930000
# 8                 Austria      Europe           32008        78.330000
# 10                Bahamas  N. America           22728        72.370000
# 11                Bahrain        Asia           22015        74.497000
# 13               Barbados  N. America           14982        73.118000
# 15                Belgium      Europe           29940        77.910000
# 21               Botswana      Africa           10107        50.567000
# 23                 Brunei        Asia           48020        75.927000
# 29                 Canada  N. America           32448        79.410000
# 33                  Chile  S. America           10435        77.010000
# ...

# %%
df[df['GDP_per_capita'] > df['GDP_per_capita'].mean()]
# Out:
#                   Country   Continent  GDP_per_capita  life_expectancy  \
# 4     Antigua and Barbuda  N. America           12738        73.544000
# 5               Argentina  S. America           10571        73.822000
# 7               Australia     Oceania           29241        79.930000
# 8                 Austria      Europe           32008        78.330000
# 10                Bahamas  N. America           22728        72.370000
# 11                Bahrain        Asia           22015        74.497000
# 13               Barbados  N. America           14982        73.118000
# 15                Belgium      Europe           29940        77.910000
# 21               Botswana      Africa           10107        50.567000
# 23                 Brunei        Asia           48020        75.927000
# 29                 Canada  N. America           32448        79.410000
# 33                  Chile  S. America           10435        77.010000
# ...

# %%
df[(df['Continent'] == 'Asia') & (df['GDP_per_capita'] > df['GDP_per_capita'].mean())]
# Out:
#                   Country Continent  GDP_per_capita  life_expectancy  \
# 11                Bahrain      Asia           22015           74.497
# 23                 Brunei      Asia           48020           75.927
# 72       Hong Kong, China      Asia           29972           80.361
# 80                 Israel      Asia           22834           78.750
# 83                  Japan      Asia           28559           81.350
# 89            Korea, Rep.      Asia           16995           76.114
# 90                 Kuwait      Asia           36397           73.133
# 100          Macao, China      Asia           22512           77.627
# 104              Malaysia      Asia           10161           72.810
# 126                  Oman      Asia           19204           72.139
# 135                 Qatar      Asia           60394           76.680
# 143          Saudi Arabia      Asia           20001           72.401
# 148             Singapore      Asia           36834           78.340
# ...

# %%
#change numbers to more readable (2 million)

df["Population"] / 1000000

#you have to define it

df["millions"] = df["Population"] / 1000000

#check the head

df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population   millions
# 0    22856302  22.856302
# 1     3071856   3.071856
# 2    30533827  30.533827
# 3    13926373  13.926373
# 4       77656   0.077656

# %%
#total GDP

df["GDP"] = df["GDP_per_capita"] * df["Population"] / 1000000

df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population   millions            GDP
# 0    22856302  22.856302   15153.728226
# 1     3071856   3.071856   12886.435920
# 2    30533827  30.533827  155661.450046
# 3    13926373  13.926373   34063.908358
# 4       77656   0.077656     989.182128

# %%
#instead of df["GDP"] you can just type df.GDP
#but if you have a space in your header column, it won't work. Only brackets

df.GDP
# Out:
# 0      1.515373e+04
# 1      1.288644e+04
# 2      1.556615e+05
# 3      3.406391e+04
# 4      9.891821e+02
# 5      3.903945e+05
# 6      6.502871e+03
# 7      5.603848e+05
# 8      2.562148e+05
# 9      2.054446e+04
# 10     6.765012e+03
# 11     1.404982e+04
# 12     1.393117e+05
# 13     4.007850e+03
# 14     5.970316e+04
# 15     3.046600e+05
# 16     1.639601e+03
# 17     8.518778e+03
# 18     1.669228e+03
# 19     2.819480e+04
# 20     2.117597e+04
# 21     1.776735e+04
# 22     1.405171e+06
# 23     1.570427e+04
# 24     5.529853e+04
# 25     1.230631e+04
# 26     2.823836e+03
# 27     1.222290e+04
# 28     2.826792e+04
# 29     9.950947e+05
#            ...
# 158    2.650285e+03
# 159    4.277668e+03
# 160    2.537548e+05
# 161    2.464757e+05
# 162    6.291488e+04
# 163    5.218551e+05
# 164    6.178980e+03
# 165    2.811552e+04
# 166    3.522788e+05
# 167    2.276934e+03
# 168    4.266219e+03
# 169    4.785104e+02
# 170    1.356144e+04
# 171    5.181952e+04
# ...

# %%
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population   millions            GDP
# 0    22856302  22.856302   15153.728226
# 1     3071856   3.071856   12886.435920
# 2    30533827  30.533827  155661.450046
# 3    13926373  13.926373   34063.908358
# 4       77656   0.077656     989.182128

# %%
#to do JOINs:
#df.merge()

# %%
df["Continent"]
# Out:
# 0            Asia
# 1          Europe
# 2          Africa
# 3          Africa
# 4      N. America
# 5      S. America
# 6          Europe
# 7         Oceania
# 8          Europe
# 9          Europe
# 10     N. America
# 11           Asia
# 12           Asia
# 13     N. America
# 14         Europe
# 15         Europe
# 16     N. America
# 17         Africa
# 18           Asia
# 19     S. America
# 20         Europe
# 21         Africa
# 22     S. America
# 23           Asia
# 24         Europe
# 25         Africa
# 26         Africa
# 27           Asia
# 28         Africa
# 29     N. America
#           ...
# 158    S. America
# 159        Africa
# 160        Europe
# 161        Europe
# 162          Asia
# 163          Asia
# 164          Asia
# 165        Africa
# 166          Asia
# 167          Asia
# 168        Africa
# 169       Oceania
# 170    N. America
# 171        Africa
# 172          Asia
# 173          Asia
# 174        Africa
# 175        Europe
# 176          Asia
# ...

# %%
#TO see only a specific number of columns our of all your columns
#You make a list our of them
df[["Continent" , "Population" , "Country"]]
# Out:
#       Continent  Population                 Country
# 0          Asia    22856302             Afghanistan
# 1        Europe     3071856                 Albania
# 2        Africa    30533827                 Algeria
# 3        Africa    13926373                  Angola
# 4    N. America       77656     Antigua and Barbuda
# 5    S. America    36930709               Argentina
# 6        Europe     3076098                 Armenia
# 7       Oceania    19164351               Australia
# 8        Europe     8004712                 Austria
# 9        Europe     8110723              Azerbaijan
# 10   N. America      297651                 Bahamas
# 11         Asia      638193                 Bahrain
# 12         Asia   129592275              Bangladesh
# 13   N. America      267511                Barbados
# 14       Europe    10057810                 Belarus
# 15       Europe    10175684                 Belgium
# 16   N. America      250512                  Belize
# ...

# %%
#Command + / (comments in and out) a line
# HOW TO SET UP GIT AND GITHUB:
#Github is where all the coders store all their codes
#you need to install and set up git
#git is a version control system
#git is a dropbox or GoogleDocs for codes.
#Github is a cloud for codes.
#it's best just because you can share codes with others
#you set up a profile and put it there
#you make repositories (collection of your codes)
#they can be private/non-private

# %%
#for mac, run this code in your termina: brew install git
# It installs it permenantly
# there is a desktop version for git. DON'T USE IT. It'll crash all the time.

# %%
#Run this

#git config --global user.name "deniseajiri.83"
#git config --global user.email "denise.ajiri83@gmail.com"

#no output = you're good

# %%
# go here: https://help.github.com/articles/set-up-git/

#Connecting over HTTPS (recommended)

#If you clone with HTTPS, you can cache your GitHub password in Git using a credential helper.

#click on "chache your GiyHub..." (https://help.github.com/articles/caching-your-github-password-in-git/) 

# when you follow the instructions, in the end if you don't get an output YOU'RE GOOD.

# %%
# go to github. click on + on the top righ and "new repository"

#initialize this repository with a README -- check this

# %%
# if you want to connect it to your machine, you clone it 
#click on "clone or download", copy the https link
#in your teminal write: git clone https:..,,,,,

# %%
# go to you folder on your computer open the read me file. make changes to it. 
#to make it saved permenantly (and making it your check point you need to:
# go into your folder in Terminal and then write this commans: git commit -a -m "Editing our README"
# then in terminal write: ls -la

# %%
# now we need to connect the computer and cloud. run in terminal: git push
#it'll ask for your username( deniseajiri83 )
#and password (shlama shlama 1)
