# %% [markdown]
# # Scraping Maryland Business Licenses with Selenium
#
# Maryland has a [great portal](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp) for searching business licenses, but the only problem is you have to check a box in order to get in.
#
# 1. Try to visit [the public search page](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp)
# 2. Get redirected to a "I agree to this" page. Click that you've read the disclaimer, click Enter the Site.
# 3. Click "Search License Records" down at the bottom of the page
# 4. You're now on the search page! From the "Jurisdiction" dropdown, select "Statewide"
# 5. In the "Trade Name" field, type "Vap%" to try to find vape shops
# 6. Click "Next" in the bottom right-hand corner to go to the next page
# 7. Click "Click for detail" to see the details for a specific business license.
#
# That's a lot of stuff! **Let's get to work.**

# %% [markdown]
# ## Preparation
#
# ### When you search for a business license, what URL should Selenium try to visit first?

# %%
#https://jportal.mdcourts.gov/license/pbPublicSearch.jsp

# %% [markdown]
# **It isn't going to work, though! It's going to redirect to that intro page.** You can use *Incognito mode* to go back through the "Check the box, etc" series of pages.
#
# ### How will you identify the checkbox to check it?
#
# Selenium can find elements by:
#
# - name
# - Class
# - ID
# - CSS selector (**ASK ME WHAT THIS IS** if you don't know)
# - XPath (**ASK ME WHAT THIS IS** because you definitely don't know)
# - Link text
# - Partial link text
#
# So in other words, what's unique about this element?
#
# - *TIP: I have a secret awesome way to do this, but you have to ask.*

# %%
#.find_element_by_xpath('//*[@id="checkbox"]').click()

# %% [markdown]
# ### How will you identify the button to select it, or the form to submit it?
#
# Selenium can submit forms by either
#
# - Selecting the form and using `.submit()`, or
# - Selecting the button and using `.click()`
#
# You only need to be able to get **one, not both.**

# %%
#.find_element_by_xpath('/html/body/table/tbody/tr[7]/td/form/div/input[2]').click()

# %% [markdown]
# ### Once you're on the next page, how will you click the "SEARCH LICENSE RECORDS" link or follow its URL?

# %%
#driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[6]/td[2]/a[2]').click()

# %% [markdown]
# ### Now you're on the form page. How do you pick "Statewide" for the jurisdiction dropdown?

# %%
#select = Select(driver.find_element_by_xpath('//*[@id="slcJurisdiction"]'))
#select.select_by_visible_taxt('Statewide)

# %% [markdown]
# ### How do you type "vap%" into the Trade Name field?

# %%
#search_input = driver.find_element_by_xpath('//*[@id="txtTradeName"]')
# search_input.send_keys('vap%')

# %% [markdown]
# ### How do you click the submit button or submit the form?

# %%
# driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/form/table/tbody/tr[14]/td/input[1]').click()

# %% [markdown]
# ### How can you find and click the 'Next' button on the search results page?

# %%
#driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr').click()

# %% [markdown]
# # Okay, let's scrape!
#
# ### Use Selenium to search for vape shops statewide, and then click through until it reaches the last page.
#
# Don't scrape yet!

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://jportal.mdcourts.gov/license/pbPublicSearch.jsp")

# %%
checkbox = driver.find_element_by_xpath('//*[@id="checkbox"]').click()
checkbox

# %%
select_button = driver.find_element_by_xpath('/html/body/table/tbody/tr[7]/td/form/div/input[2]').click()
select_button

# %%
licence = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[6]/td[2]/a[2]').click()
license
# Out:
# Type license() to see the full license text

# %%
select = Select(driver.find_element_by_xpath('//*[@id="slcJurisdiction"]'))
select.select_by_visible_text('Statewide')

# %%
search_input = driver.find_element_by_xpath('//*[@id="txtTradeName"]')
search_input.send_keys('vap%')

# %%
submit = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/form/table/tbody/tr[14]/td/input[1]').click()
submit

# %%
next_button = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr')
#next_button.click()

# %%
from bs4 import BeautifulSoup
doc=BeautifulSoup(driver.page_source, 'html.parser')

# %% [markdown]
# ### Use Selenium to scrape the first page of search results for vape shops statewide (well, we'll try).
#
# - *TIP: You can find elements/text using Selenium, or use BeautifulSoup with `doc = BeautifulSoup(driver.page_source)`*
#
# I've included some BeautifulSoup code that might be helpful. If you use it, **ask me how I made it.** It's important.

# %%
# IF YOU ARE USING BEAUTIFULSOUP, HERE IS SOME SAMPLE CODE
# IF YOU USE THIS CODE, ASK ME HOW I MADE IT. IT'S IMPORTANT.
business_headers = doc.find_all('tr',class_='searchfieldtitle')
len(business_headers)
# Out:
# 5

# %%
# You'll probably need to find specific tds inside
# of the rows instead of looking at the whole thing.
my_list = []
for header in business_headers:
    current = {}
    rows = header.find_next_siblings('tr')
    #print("HEADER is", header.text.strip())
    current['trade_name']= header.find_all('td')[1].text.strip()
    #print("ROW 0 IS", rows[0].text.strip())
    current['name']= rows[0].find_all('td')[1].text.strip()
    current['status'] = rows[0].find_all('td')[2].text.strip()
    #print("ROW 1 IS", rows[1].text.strip())
    current['license']= rows[1].find_all('td')[2].text.strip()
    current['address']= rows[1].find_all('td')[1].text.strip()
    #print("ROW 2 IS", rows[2].text.strip())
    current['date'] = rows[2].find_all('td')[2].text.strip()
    current['city'] = rows[2].find_all('td')[1].text.strip()
    #print("ROW 3 IS", rows[3].text.strip())
    current['county'] = rows[3].text.strip()
    my_list.append(current)
    #print("----")

# %%
my_list
# Out:
# [{'address': '1015 S SALISBURY BLVD',
#   'city': 'SALISBURY, MD 21801',
#   'county': 'Wicomico County',
#   'date': 'Issued Date: 4/27/2017',
#   'license': 'License: 22173808',
#   'name': 'AMIN NARGIS',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPE IT STORE II'},
#  {'address': '1724 N SALISBURY BLVD UNIT 2',
#   'city': 'SALISBURY, MD 21801',
#   'county': 'Wicomico County',
#   'date': 'Issued Date: 4/27/2017',
#   'license': 'License: 22173807',
#   'name': 'AMIN NARGIS',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPE IT STORE I'},
#  {'address': '2299 JOHNS HOPKINS ROAD',
#   'city': 'GAMBRILLS, MD 21054',
#   'county': 'Anne Arundel County',
#   'date': 'Issued Date: 4/05/2017',
#   'license': 'License: 02104436',
#   'name': 'ANJ DISTRIBUTIONS LLC',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPEPAD THE'},
#  {'address': '110 S. PINEY RD',
#   'city': 'CHESTER, MD 21619',
#   'county': "Queen Anne's County",
#   'date': 'Issued Date: 5/31/2017',
#   'license': 'License: 17165957',
#   'name': 'COX TRADING COMPANY L L C',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPE FROG'},
#  {'address': '346 RITCHIE HIGHWAY',
#   'city': 'SEVERNA PARK, MD 21146',
#   'county': 'Anne Arundel County',
#   'date': '',
#   'license': '',
#   'name': 'COX TRADING LLC',
#   'status': 'Lic. Status: Pending',
#   'trade_name': 'VAPE FROG'}]

# %% [markdown]
# ### Save these into `vape-results.csv`

# %%
import pandas as pd
df = pd.DataFrame(my_list)
df.head
# Out:
# <bound method NDFrame.head of                         address                    city               county  \
# 0         1015 S SALISBURY BLVD     SALISBURY, MD 21801      Wicomico County
# 1  1724 N SALISBURY BLVD UNIT 2     SALISBURY, MD 21801      Wicomico County
# 2       2299 JOHNS HOPKINS ROAD     GAMBRILLS, MD 21054  Anne Arundel County
# 3               110 S. PINEY RD       CHESTER, MD 21619  Queen Anne's County
# 4           346 RITCHIE HIGHWAY  SEVERNA PARK, MD 21146  Anne Arundel County
#
#                      date            license                       name  \
# 0  Issued Date: 4/27/2017  License: 22173808                AMIN NARGIS
# 1  Issued Date: 4/27/2017  License: 22173807                AMIN NARGIS
# 2  Issued Date: 4/05/2017  License: 02104436      ANJ DISTRIBUTIONS LLC
# 3  Issued Date: 5/31/2017  License: 17165957  COX TRADING COMPANY L L C
# 4                                                       COX TRADING LLC
#
#                  status        trade_name
# 0   Lic. Status: Issued  VAPE IT STORE II
# 1   Lic. Status: Issued   VAPE IT STORE I
# 2   Lic. Status: Issued       VAPEPAD THE
# 3   Lic. Status: Issued         VAPE FROG
# 4  Lic. Status: Pending         VAPE FROG  >

# %% [markdown]
# ### Open `vape-results.csv` to make sure there aren't any extra weird columns

# %%
df.to_csv("vape-results.csv" , index = False)
vape_df = pd.read_csv('vape-results.csv')
vape_df.head()
# Out:
#                         address                    city               county  \
# 0         1015 S SALISBURY BLVD     SALISBURY, MD 21801      Wicomico County
# 1  1724 N SALISBURY BLVD UNIT 2     SALISBURY, MD 21801      Wicomico County
# 2       2299 JOHNS HOPKINS ROAD     GAMBRILLS, MD 21054  Anne Arundel County
# 3               110 S. PINEY RD       CHESTER, MD 21619  Queen Anne's County
# 4           346 RITCHIE HIGHWAY  SEVERNA PARK, MD 21146  Anne Arundel County
#
#                      date            license                       name  \
# 0  Issued Date: 4/27/2017  License: 22173808                AMIN NARGIS
# 1  Issued Date: 4/27/2017  License: 22173807                AMIN NARGIS
# 2  Issued Date: 4/05/2017  License: 02104436      ANJ DISTRIBUTIONS LLC
# 3  Issued Date: 5/31/2017  License: 17165957  COX TRADING COMPANY L L C
# 4                     NaN                NaN            COX TRADING LLC
#
#                  status        trade_name
# 0   Lic. Status: Issued  VAPE IT STORE II
# 1   Lic. Status: Issued   VAPE IT STORE I
# 2   Lic. Status: Issued       VAPEPAD THE
# 3   Lic. Status: Issued         VAPE FROG
# 4  Lic. Status: Pending         VAPE FROG

# %% [markdown]
# ## Use Selenium to scrape ALL pages of results, save the results into `vape-results-all.csv`.

# %%
my_final_list =[]
while True:
    try:
        doc=BeautifulSoup(driver.page_source, 'html.parser')
        biz_headers = doc.find_all('tr',class_='searchfieldtitle')
        for header in biz_headers:
            current = {}
            rows = header.find_next_siblings('tr')
            current['trade_name']= header.find_all('td')[1].text.strip()
            current['name']= rows[0].find_all('td')[1].text.strip()
            current['status'] = rows[0].find_all('td')[2].text.strip()
            current['license']= rows[1].find_all('td')[2].text.strip()
            current['address']= rows[1].find_all('td')[1].text.strip()
            current['date'] = rows[2].find_all('td')[2].text.strip()
            current['city'] = rows[2].find_all('td')[1].text.strip()
            current['county'] = rows[3].text.strip()
            my_final_list.append(current)
        next_button = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr')
        next_button.click()
    except:
        break
my_final_list
# Out:
# [{'address': '1015 S SALISBURY BLVD',
#   'city': 'SALISBURY, MD 21801',
#   'county': 'Wicomico County',
#   'date': 'Issued Date: 4/27/2017',
#   'license': 'License: 22173808',
#   'name': 'AMIN NARGIS',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPE IT STORE II'},
#  {'address': '1724 N SALISBURY BLVD UNIT 2',
#   'city': 'SALISBURY, MD 21801',
#   'county': 'Wicomico County',
#   'date': 'Issued Date: 4/27/2017',
#   'license': 'License: 22173807',
#   'name': 'AMIN NARGIS',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPE IT STORE I'},
#  {'address': '2299 JOHNS HOPKINS ROAD',
#   'city': 'GAMBRILLS, MD 21054',
#   'county': 'Anne Arundel County',
#   'date': 'Issued Date: 4/05/2017',
#   'license': 'License: 02104436',
#   'name': 'ANJ DISTRIBUTIONS LLC',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPEPAD THE'},
#  {'address': '110 S. PINEY RD',
#   'city': 'CHESTER, MD 21619',
#   'county': "Queen Anne's County",
#   'date': 'Issued Date: 5/31/2017',
#   'license': 'License: 17165957',
#   'name': 'COX TRADING COMPANY L L C',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPE FROG'},
#  {'address': '346 RITCHIE HIGHWAY',
#   'city': 'SEVERNA PARK, MD 21146',
#   'county': 'Anne Arundel County',
#   'date': '',
#   'license': '',
#   'name': 'COX TRADING LLC',
#   'status': 'Lic. Status: Pending',
#   'trade_name': 'VAPE FROG'},
#  {'address': '185 MITCHELLS CHANCE RD',
#   'city': 'EDGEWATER, MD 21037',
#   'county': 'Anne Arundel County',
#   'date': 'Issued Date: 4/13/2017',
#   'license': 'License: 02102408',
#   'name': 'DISBROW II EMERSON HARRINGTON',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPE LOFT (THE)'},
#  {'address': '7104 MINSTREL UNIT #7',
#   'city': 'COLUMBIA, MD 21045',
#   'county': 'Howard County',
#   'date': 'Issued Date: 5/19/2017',
#   'license': 'License: 13141786',
#   'name': 'DISCOUNT TOBACCO ESSEX LLC',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPE N CIGAR'},
#  {'address': '330 ONE FORTY VILLAGE ROAD',
#   'city': 'WESTMINSTER, MD 21157',
#   'county': 'Carroll County',
#   'date': 'Issued Date: 4/21/2017',
#   'license': 'License: 06126253',
#   'name': 'FAIRGROUND VILLAGE LLC',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPE DOJO'},
#  {'address': '29890 THREE NOTCH ROAD',
#   'city': 'CHARLOTTE HALL, MD 20622',
#   'county': "St. Mary's County",
#   'date': '',
#   'license': '',
#   'name': 'GRIMM JENNIFER',
#   'status': 'Lic. Status: Pending',
#   'trade_name': 'VAPE HAVEN'},
#  {'address': '356 ROMANCOKE ROAD',
#   'city': 'STEVENSVILLE, MD 21666',
#   'county': "Queen Anne's County",
#   'date': 'Issued Date: 4/13/2017',
#   'license': 'License: 17166688',
#   'name': 'HUTCH VAPES LLC',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPE BIRD'},
#  {'address': '110 S PINEY ROAD  STE 106',
#   'city': 'CHESTER, MD 21619',
#   'county': "Queen Anne's County",
#   'date': '',
#   'license': '',
#   'name': 'HUTCHINS COX LLP',
#   'status': 'Lic. Status: Pending',
#   'trade_name': 'VAPE FROG'},
#  {'address': '28943 THREE NOTCH ROAD',
#   'city': 'MECHANICSVILLE, MD 20659',
#   'county': "St. Mary's County",
#   'date': 'Issued Date: 5/17/2017',
#   'license': 'License: 18167503',
#   'name': 'JAMESON WILLIAM',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPORS LOUNGE'},
#  {'address': '6843 CRAIN HIGHWAY',
#   'city': 'LA PLATA, MD 20646',
#   'county': 'Charles County',
#   'date': '',
#   'license': '',
#   'name': 'JAMESON WILLIAM E',
#   'status': 'Lic. Status: Pending',
#   'trade_name': 'VAPORS LOUNGE'},
#  {'address': '6321 OLD BRANCH AVE',
#   'city': 'CAMP SPRINGS, MD 20748',
#   'county': "St. Mary's County",
#   'date': '',
#   'license': '',
#   'name': 'JEFFERS MICHAEL',
#   'status': 'Lic. Status: Pending',
#   'trade_name': 'VAPIST MD'},
#  {'address': '6321 OLD BRANCH AVE',
#   'city': 'CAMP SPRINGS, MD 20748',
#   'county': "Prince George's County",
#   'date': '',
#   'license': '',
#   'name': 'JEFFERS MICHAEL W',
#   'status': 'Lic. Status: Pending',
#   'trade_name': 'VAPIST MD LLC'},
#  {'address': '7954 B AND A BLVD',
#   'city': 'GLEN BURNIE, MD 21060',
#   'county': 'Anne Arundel County',
#   'date': '',
#   'license': '',
#   'name': 'SHIN JENNY Y',
#   'status': 'Lic. Status: Pending',
#   'trade_name': 'VAPERTETMD'},
#  {'address': '6325 WASHINGTON BLVD',
#   'city': 'ELKRIDGE, MD 21075',
#   'county': 'Howard County',
#   'date': '',
#   'license': '',
#   'name': 'SHIN JENNY YOUNG',
#   'status': 'Lic. Status: Pending',
#   'trade_name': 'VAPERTEKMD'},
#  {'address': '3203 NORTH POINT RD',
#   'city': 'BALTIMORE, MD 21222',
#   'county': 'Baltimore County',
#   'date': '',
#   'license': '',
#   'name': 'TAYLOR TRAVIS',
#   'status': 'Lic. Status: Pending',
#   'trade_name': 'VAPORIOT'},
#  {'address': '519 LINDEN AVENUE UNIT 6',
#   'city': 'POCOMOKE CITY, MD 21851',
#   'county': 'Worcester County',
#   'date': 'Issued Date: 5/05/2017',
#   'license': 'License: 23178140',
#   'name': 'TRUE ENTERPRISE INC',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPE PLUS'},
#  {'address': '16521 S FREDERICK AVE',
#   'city': 'GAITHERSBURG, MD 20877',
#   'county': 'Montgomery County',
#   'date': 'Issued Date: 4/18/2017',
#   'license': 'License: 15155429',
#   'name': 'VAPE  SOCIAL  LLC',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPE  SOCIAL'},
#  {'address': '2070 CRAIN HIGHWAY  UNIT F',
#   'city': 'WALDORF, MD 20601',
#   'county': 'Charles County',
#   'date': 'Issued Date: 3/31/2017',
#   'license': 'License: 08131285',
#   'name': 'VAPE JUNGLE LLC',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPE JUNGLE'},
#  {'address': '4130 E JOPPA RD UNIT 109',
#   'city': 'NOTTINGHAM, MD 21236',
#   'county': 'Baltimore County',
#   'date': '',
#   'license': '',
#   'name': 'VAPE TIME LLC',
#   'status': 'Lic. Status: Pending',
#   'trade_name': 'VAPE TIME'},
#  {'address': '11110 MALL CIRCLE',
#   'city': 'WALDORF, MD 20603',
#   'county': 'Charles County',
#   'date': '',
#   'license': '',
#   'name': 'VAPEBAR EXPRESS LLC',
#   'status': 'Lic. Status: Pending',
#   'trade_name': 'VAPEBAR EXPESS'},
#  {'address': '3524 CRAIN HWY',
#   'city': 'BOWIE, MD 20716',
#   'county': "Prince George's County",
#   'date': 'Issued Date: 5/03/2017',
#   'license': 'License: 16165362',
#   'name': 'VAPOR 99 LLC',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPOR 99'},
#  {'address': '8117 OCEAN GATEWAY UNIT #4',
#   'city': 'EASTON, MD 21601',
#   'county': 'Talbot County',
#   'date': 'Issued Date: 5/10/2017',
#   'license': 'License: 20170900',
#   'name': 'VAPOR ALLEY LLC',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPOR ALLEY'},
#  {'address': '11717 OLD NATIONAL PIKE',
#   'city': 'NEW MARKET, MD 21774',
#   'county': 'Frederick County',
#   'date': 'Issued Date: 4/14/2017',
#   'license': 'License: 10135432',
#   'name': 'VAPOR EMPORIUM MD LLC',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPOR EMPORIUM'},
#  {'address': '1913 LANSDOWNE ROAD SUITE E',
#   'city': 'BALTIMORE, MD 21227',
#   'county': 'Baltimore County',
#   'date': 'Issued Date: 4/12/2017',
#   'license': 'License: 03121958',
#   'name': 'VAPOR VILLA CORP',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPOR VILLA'},
#  {'address': '730 FREDERICK ROAD',
#   'city': 'CATONSVILLE, MD 21228',
#   'county': 'Baltimore County',
#   'date': 'Issued Date: 4/12/2017',
#   'license': 'License: 03121959',
#   'name': 'VAPOR VILLA CORP',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPOR VILLA'},
#  {'address': '138 N BOND STREET',
#   'city': 'BEL AIR, MD 21014',
#   'county': 'Harford County',
#   'date': 'Issued Date: 4/03/2017',
#   'license': 'License: 12140135',
#   'name': 'WALKER TRADING CO INC',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPE DOJO'},
#  {'address': '11600 CROSSROAD CIR  STE E',
#   'city': 'BALTIMORE, MD 21220',
#   'county': 'Baltimore County',
#   'date': '',
#   'license': '',
#   'name': 'WALKER TRADING COMPANY INC',
#   'status': 'Lic. Status: Pending',
#   'trade_name': 'VAPE DOJO'},
#  {'address': '3570 SAINT JOHNS LANE, SUITE 109',
#   'city': 'ELLICOTT CITY, MD 21042',
#   'county': 'Howard County',
#   'date': 'Issued Date: 3/27/2017',
#   'license': 'License: 13144108',
#   'name': 'WALKER TRADING COMPANY INC',
#   'status': 'Lic. Status: Issued',
#   'trade_name': 'VAPE DOJO'},
#  {'address': '3315 PLAZA WAY',
#   'city': 'WALDORF, MD 20603',
#   'county': 'Charles County',
#   'date': '',
#   'license': '',
#   'name': 'YARKHOUSE EMPIRE INC',
#   'status': 'Lic. Status: Pending',
#   'trade_name': 'VAPEZ YARDHOUSE'}]

# %%
len(my_final_list)
# Out:
# 32

# %%
df = pd.DataFrame(my_final_list)
df.head()
# Out:
#                         address                    city               county  \
# 0         1015 S SALISBURY BLVD     SALISBURY, MD 21801      Wicomico County
# 1  1724 N SALISBURY BLVD UNIT 2     SALISBURY, MD 21801      Wicomico County
# 2       2299 JOHNS HOPKINS ROAD     GAMBRILLS, MD 21054  Anne Arundel County
# 3               110 S. PINEY RD       CHESTER, MD 21619  Queen Anne's County
# 4           346 RITCHIE HIGHWAY  SEVERNA PARK, MD 21146  Anne Arundel County
#
#                      date            license                       name  \
# 0  Issued Date: 4/27/2017  License: 22173808                AMIN NARGIS
# 1  Issued Date: 4/27/2017  License: 22173807                AMIN NARGIS
# 2  Issued Date: 4/05/2017  License: 02104436      ANJ DISTRIBUTIONS LLC
# 3  Issued Date: 5/31/2017  License: 17165957  COX TRADING COMPANY L L C
# 4                                                       COX TRADING LLC
#
#                  status        trade_name
# 0   Lic. Status: Issued  VAPE IT STORE II
# 1   Lic. Status: Issued   VAPE IT STORE I
# 2   Lic. Status: Issued       VAPEPAD THE
# 3   Lic. Status: Issued         VAPE FROG
# 4  Lic. Status: Pending         VAPE FROG

# %%
df.to_csv("vape-results-all.csv" , index = False)
vape_df = pd.read_csv('vape-results-all.csv')
vape_df.head(32)
# Out:
#                              address                      city  \
# 0              1015 S SALISBURY BLVD       SALISBURY, MD 21801
# 1       1724 N SALISBURY BLVD UNIT 2       SALISBURY, MD 21801
# 2            2299 JOHNS HOPKINS ROAD       GAMBRILLS, MD 21054
# 3                    110 S. PINEY RD         CHESTER, MD 21619
# 4                346 RITCHIE HIGHWAY    SEVERNA PARK, MD 21146
# 5            185 MITCHELLS CHANCE RD       EDGEWATER, MD 21037
# 6              7104 MINSTREL UNIT #7        COLUMBIA, MD 21045
# 7         330 ONE FORTY VILLAGE ROAD     WESTMINSTER, MD 21157
# 8             29890 THREE NOTCH ROAD  CHARLOTTE HALL, MD 20622
# 9                 356 ROMANCOKE ROAD    STEVENSVILLE, MD 21666
# 10         110 S PINEY ROAD  STE 106         CHESTER, MD 21619
# 11            28943 THREE NOTCH ROAD  MECHANICSVILLE, MD 20659
# 12                6843 CRAIN HIGHWAY        LA PLATA, MD 20646
# 13               6321 OLD BRANCH AVE    CAMP SPRINGS, MD 20748
# 14               6321 OLD BRANCH AVE    CAMP SPRINGS, MD 20748
# 15                 7954 B AND A BLVD     GLEN BURNIE, MD 21060
# 16              6325 WASHINGTON BLVD        ELKRIDGE, MD 21075
# 17               3203 NORTH POINT RD       BALTIMORE, MD 21222
# 18          519 LINDEN AVENUE UNIT 6   POCOMOKE CITY, MD 21851
# 19             16521 S FREDERICK AVE    GAITHERSBURG, MD 20877
# 20        2070 CRAIN HIGHWAY  UNIT F         WALDORF, MD 20601
# 21          4130 E JOPPA RD UNIT 109      NOTTINGHAM, MD 21236
# 22                 11110 MALL CIRCLE         WALDORF, MD 20603
# 23                    3524 CRAIN HWY           BOWIE, MD 20716
# 24        8117 OCEAN GATEWAY UNIT #4          EASTON, MD 21601
# 25           11717 OLD NATIONAL PIKE      NEW MARKET, MD 21774
# 26       1913 LANSDOWNE ROAD SUITE E       BALTIMORE, MD 21227
# 27                730 FREDERICK ROAD     CATONSVILLE, MD 21228
# 28                 138 N BOND STREET         BEL AIR, MD 21014
# 29        11600 CROSSROAD CIR  STE E       BALTIMORE, MD 21220
# 30  3570 SAINT JOHNS LANE, SUITE 109   ELLICOTT CITY, MD 21042
# 31                    3315 PLAZA WAY         WALDORF, MD 20603
#
#                     county                    date            license  \
# 0          Wicomico County  Issued Date: 4/27/2017  License: 22173808
# 1          Wicomico County  Issued Date: 4/27/2017  License: 22173807
# 2      Anne Arundel County  Issued Date: 4/05/2017  License: 02104436
# 3      Queen Anne's County  Issued Date: 5/31/2017  License: 17165957
# 4      Anne Arundel County                     NaN                NaN
# 5      Anne Arundel County  Issued Date: 4/13/2017  License: 02102408
# 6            Howard County  Issued Date: 5/19/2017  License: 13141786
# 7           Carroll County  Issued Date: 4/21/2017  License: 06126253
# 8        St. Mary's County                     NaN                NaN
# 9      Queen Anne's County  Issued Date: 4/13/2017  License: 17166688
# 10     Queen Anne's County                     NaN                NaN
# 11       St. Mary's County  Issued Date: 5/17/2017  License: 18167503
# 12          Charles County                     NaN                NaN
# 13       St. Mary's County                     NaN                NaN
# 14  Prince George's County                     NaN                NaN
# 15     Anne Arundel County                     NaN                NaN
# 16           Howard County                     NaN                NaN
# 17        Baltimore County                     NaN                NaN
# 18        Worcester County  Issued Date: 5/05/2017  License: 23178140
# 19       Montgomery County  Issued Date: 4/18/2017  License: 15155429
# 20          Charles County  Issued Date: 3/31/2017  License: 08131285
# 21        Baltimore County                     NaN                NaN
# 22          Charles County                     NaN                NaN
# 23  Prince George's County  Issued Date: 5/03/2017  License: 16165362
# 24           Talbot County  Issued Date: 5/10/2017  License: 20170900
# 25        Frederick County  Issued Date: 4/14/2017  License: 10135432
# 26        Baltimore County  Issued Date: 4/12/2017  License: 03121958
# 27        Baltimore County  Issued Date: 4/12/2017  License: 03121959
# 28          Harford County  Issued Date: 4/03/2017  License: 12140135
# 29        Baltimore County                     NaN                NaN
# 30           Howard County  Issued Date: 3/27/2017  License: 13144108
# 31          Charles County                     NaN                NaN
#
#                              name                status        trade_name
# 0                     AMIN NARGIS   Lic. Status: Issued  VAPE IT STORE II
# 1                     AMIN NARGIS   Lic. Status: Issued   VAPE IT STORE I
# 2           ANJ DISTRIBUTIONS LLC   Lic. Status: Issued       VAPEPAD THE
# 3       COX TRADING COMPANY L L C   Lic. Status: Issued         VAPE FROG
# 4                 COX TRADING LLC  Lic. Status: Pending         VAPE FROG
# 5   DISBROW II EMERSON HARRINGTON   Lic. Status: Issued   VAPE LOFT (THE)
# 6      DISCOUNT TOBACCO ESSEX LLC   Lic. Status: Issued      VAPE N CIGAR
# 7          FAIRGROUND VILLAGE LLC   Lic. Status: Issued         VAPE DOJO
# 8                  GRIMM JENNIFER  Lic. Status: Pending        VAPE HAVEN
# 9                 HUTCH VAPES LLC   Lic. Status: Issued         VAPE BIRD
# 10               HUTCHINS COX LLP  Lic. Status: Pending         VAPE FROG
# 11                JAMESON WILLIAM   Lic. Status: Issued     VAPORS LOUNGE
# 12              JAMESON WILLIAM E  Lic. Status: Pending     VAPORS LOUNGE
# 13                JEFFERS MICHAEL  Lic. Status: Pending         VAPIST MD
# 14              JEFFERS MICHAEL W  Lic. Status: Pending     VAPIST MD LLC
# 15                   SHIN JENNY Y  Lic. Status: Pending        VAPERTETMD
# 16               SHIN JENNY YOUNG  Lic. Status: Pending        VAPERTEKMD
# 17                  TAYLOR TRAVIS  Lic. Status: Pending          VAPORIOT
# 18            TRUE ENTERPRISE INC   Lic. Status: Issued         VAPE PLUS
# 19              VAPE  SOCIAL  LLC   Lic. Status: Issued      VAPE  SOCIAL
# 20                VAPE JUNGLE LLC   Lic. Status: Issued       VAPE JUNGLE
# 21                  VAPE TIME LLC  Lic. Status: Pending         VAPE TIME
# 22            VAPEBAR EXPRESS LLC  Lic. Status: Pending    VAPEBAR EXPESS
# 23                   VAPOR 99 LLC   Lic. Status: Issued          VAPOR 99
# 24                VAPOR ALLEY LLC   Lic. Status: Issued       VAPOR ALLEY
# 25          VAPOR EMPORIUM MD LLC   Lic. Status: Issued    VAPOR EMPORIUM
# 26               VAPOR VILLA CORP   Lic. Status: Issued       VAPOR VILLA
# 27               VAPOR VILLA CORP   Lic. Status: Issued       VAPOR VILLA
# 28          WALKER TRADING CO INC   Lic. Status: Issued         VAPE DOJO
# 29     WALKER TRADING COMPANY INC  Lic. Status: Pending         VAPE DOJO
# 30     WALKER TRADING COMPANY INC   Lic. Status: Issued         VAPE DOJO
# 31           YARKHOUSE EMPIRE INC  Lic. Status: Pending   VAPEZ YARDHOUSE
