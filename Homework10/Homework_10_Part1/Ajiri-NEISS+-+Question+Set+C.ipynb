# %% [markdown]
# # Exercise: NEISS, Question Set C
#
# #### Summary
#
# The [National Electronic Injury Surveillance System](https://www.cpsc.gov/Safety-Education/Safety-Guides/General-Information/National-Electronic-Injury-Surveillance-System-NEISS) is a data product produced by the US Consumer Product Safety Commission. It tracks emergency room injuries related to consumer products (e.g., "a door fell on me!").
#
# #### Files
#
# - **nss15.tsv**: injury data (one injury per row)
# - **2017NEISSCodingManualCPSConlyNontrauma.pdf**: column definitions and explanations
# - **2015 Neiss data highlights.pdf**: a partial summary of the data
# - **2017ComparabilityTable.pdf**: product code definitions
# - **categories-cleaned.txt**: product code definitions in CSV format (great for joining!)
#
# #### Source
#
# https://www.cpsc.gov/Safety-Education/Safety-Guides/General-Information/National-Electronic-Injury-Surveillance-System-NEISS
#
# #### Skills
#
# - Reading tab-separated files
# - Ignoring bad lines
# - Replacing values
# - Using numpy/`np.nan`
# - String search using regular expressions
# - Averages practice
# - Converting `.value_counts()` and similar results into DataFrames

# %% [markdown]
# # Read in `nss15.tsv`
#
# Some of the lines just **aren't formatted correctly**. Maybe we can avoid those?

# %%
#tsv has tabs instead of commas. So change the separator (sep) to read it as tags 
import pandas as pd
# %matplotlib inline
df = pd.read_csv('nss15.tsv', sep = "\t", error_bad_lines = False, dtype= {'prod1': str, 'prod2': str})
df.head()
# Out:
# b'Skipping line 10822: expected 19 fields, saw 20\n'
# b'Skipping line 48623: expected 19 fields, saw 20\nSkipping line 62534: expected 19 fields, saw 20\n'
# b'Skipping line 103739: expected 19 fields, saw 20\n'
# b'Skipping line 135495: expected 19 fields, saw 20\nSkipping line 151678: expected 19 fields, saw 20\n'
# b'Skipping line 237135: expected 19 fields, saw 20\nSkipping line 240597: expected 19 fields, saw 20\n'
# b'Skipping line 274270: expected 19 fields, saw 20\nSkipping line 277461: expected 19 fields, saw 20\n'
#    CPSC Case #   trmt_date  psu   weight stratum  age  sex  race race_other  \
# 0    150733174  07/11/2015   38  15.7762       V    5    1     0        NaN
# 1    150734723  07/06/2015   43  83.2157       S   36    1     1        NaN
# 2    150817487  08/02/2015   51  74.8813       L   20    2     0        NaN
# 3    150717776  06/26/2015   41  15.7762       V   61    1     0        NaN
# 4    150721694  07/04/2015   42  74.8813       L   88    2     3   HISPANIC
#
#    diag      diag_other  body_part  disposition  location  fmv prod1 prod2  \
# 0    57             NaN         33            1         9    0  1267   NaN
# 1    57             NaN         34            1         1    0  1439  4057
# 2    71  OTITIS EXTERNA         94            1         0    0  3274   NaN
# 3    71            PAIN         35            1         0    0   611   NaN
# 4    62             NaN         75            1         0    0  1893  1807
#
#                                                narr1  \
# 0  5 YR OLD MALE PLAYING SOCCER BLOCKING BALL AND...
# 1  L WRIST FX(?)/36YOWM 2 WKS AGO@G-FRIENDS HM,MO...
# 2  20 YO F C/O EAR PAIN 1 DAY SAS WAS SWIMMING YE...
# 3  61YOM W/KNEE PAIN S/P FALLING IN SHOWER 2 DAYS...
# 4  88YOF PAIN TO HEAD WHEN FALL TO FLOOR WHEN WAL...
#
#                                                narr2
# 0                                               X IT
# 1  AN OBJECT&TWISTED WRIST TRYING TO CONTOL MOWER...
# 2  T TRIED TO USE ***S TO REMOVE WAX MADE IT WORS...
# 3                                                NaN
# 4           DOOR AND FELL.DENIES LOC. DX HEAD INJURY

# %%
#series , sort_values() or sort_index()... index is the far-left line when you do value counts and
#whatever comes after that is values.
#to make a new df you always need to filter.. df_wall - df[df.....]

# %% [markdown]
# ### Check that your dataframe has 357727 rows and 19 columns.

# %%
df.shape
# Out:
# (357727, 19)

# %% [markdown]
# ### List the columns and their data types

# %%
df.columns
# Out:
# Index(['CPSC Case #', 'trmt_date', 'psu', 'weight', 'stratum', 'age', 'sex',
#        'race', 'race_other', 'diag', 'diag_other', 'body_part', 'disposition',
#        'location', 'fmv', 'prod1', 'prod2', 'narr1', 'narr2'],
#       dtype='object')

# %%
df.dtypes
# Out:
# CPSC Case #      int64
# trmt_date       object
# psu              int64
# weight         float64
# stratum         object
# age              int64
# sex              int64
# race             int64
# race_other      object
# diag             int64
# diag_other      object
# body_part        int64
# disposition      int64
# location         int64
# fmv              int64
# prod1           object
# prod2           object
# narr1           object
# narr2           object
# dtype: object

# %% [markdown]
# ### What does each column mean?

# %%
#treatment date, prod = product used, narr2 = narrative given about accident, narr1 = patient description

# %% [markdown]
# # Cleaning up a column
#
# Take a look at the **sex** column. How many rows of each sex are there?

# %%
#male is 1, female is 2, 0 is not recorded 
df['sex'].value_counts()
# Out:
# 1    195071
# 2    162654
# 0         2
# Name: sex, dtype: int64

# %% [markdown]
# ## Replace the numbers with the appropriate words they stand for.
#
# Those numbers are terrible - codes are fine for storage but not really for reading. **Replace the numbers with the  words they stand for.**
#
# Refer to page 7 of the column definitions file.

# %%
#save into column and then the dataframe 
df.sex = df['sex'].replace(1,'Male')
df.sex = df['sex'].replace(2, 'Female')
df.sex = df['sex'].replace(0, 'Not Recorded')
df.head()
# Out:
#    CPSC Case #   trmt_date  psu   weight stratum  age     sex  race  \
# 0    150733174  07/11/2015   38  15.7762       V    5    Male     0
# 1    150734723  07/06/2015   43  83.2157       S   36    Male     1
# 2    150817487  08/02/2015   51  74.8813       L   20  Female     0
# 3    150717776  06/26/2015   41  15.7762       V   61    Male     0
# 4    150721694  07/04/2015   42  74.8813       L   88  Female     3
#
#   race_other  diag      diag_other  body_part  disposition  location  fmv  \
# 0        NaN    57             NaN         33            1         9    0
# 1        NaN    57             NaN         34            1         1    0
# 2        NaN    71  OTITIS EXTERNA         94            1         0    0
# 3        NaN    71            PAIN         35            1         0    0
# 4   HISPANIC    62             NaN         75            1         0    0
#
#   prod1 prod2                                              narr1  \
# 0  1267   NaN  5 YR OLD MALE PLAYING SOCCER BLOCKING BALL AND...
# 1  1439  4057  L WRIST FX(?)/36YOWM 2 WKS AGO@G-FRIENDS HM,MO...
# 2  3274   NaN  20 YO F C/O EAR PAIN 1 DAY SAS WAS SWIMMING YE...
# 3   611   NaN  61YOM W/KNEE PAIN S/P FALLING IN SHOWER 2 DAYS...
# 4  1893  1807  88YOF PAIN TO HEAD WHEN FALL TO FLOOR WHEN WAL...
#
#                                                narr2
# 0                                               X IT
# 1  AN OBJECT&TWISTED WRIST TRYING TO CONTOL MOWER...
# 2  T TRIED TO USE ***S TO REMOVE WAX MADE IT WORS...
# 3                                                NaN
# 4           DOOR AND FELL.DENIES LOC. DX HEAD INJURY

# %% [markdown]
# ## Confirm you have 195071 male, 162654 female, and 2 "Not Recorded."

# %%
df['sex'].value_counts()
# Out:
# Male            195071
# Female          162654
# Not Recorded         2
# Name: sex, dtype: int64

# %% [markdown]
# ## Graph the number of men and women, but don’t included the “Not Recorded” records

# %%
#you can plot() dataframe with value counts! 
df['sex'].value_counts().plot(kind = 'barh')

# %%
recorded = df[df.sex != 'Not Recorded'].sex.value_counts()
recorded.plot(kind = 'barh')

# %% [markdown]
# ## "Not recorded" seems silly - change it to be `NaN` instead
#
# Don't use `na_values` for this.

# %%
#want to talk about NaN? We need numpy. Numpy is the number stuff underneath pandas 
import numpy as np
np.nan
# Out:
# nan

# %%
df['sex'].replace('Not Recorded', np.nan, inplace=True)
df['sex'].value_counts(dropna=False)
#want to still see the NaN values? value_counts(dropna=False)
# Out:
# Male      195071
# Female    162654
# NaN            2
# Name: sex, dtype: int64

# %% [markdown]
# ## Graph the count of men and women, but don’t included the “Not Recorded” records
#
# Yes, again! The code you use should be different this time.

# %%
df['sex'].value_counts().plot(kind = 'barh')

# %% [markdown]
# # Wall punching

# %% [markdown]
# ## Find every instance where the narrative includes punching a wall
#
# Include phrases like "punched a wall" or "punch wall" or "punched ten thousand walls." Do not type them each individually. How do you do that?????

# %%
df['narr1'].value_counts().head()
# Out:
# 17 YO MALE PLAYING BASKETBALL.  DX ANKLE SPRAIN      12
# 14 YO MALE PLAYING BASKETBALL.  DX ANKLE SPRAIN      12
# 16 YO MALE PLAYING BASKETBALL.  DX ANKLE SPRAIN      11
# 15 YO MALE PLAYING BASKETBALL.  DX ANKLE SPRAIN      11
# 9YOF GOT EAR INFECTION AFTER SWIMMING;  DX OTITIS     8
# Name: narr1, dtype: int64

# %%
#find fell off bike in regex 
#df[df.narr1.str.contains('F[AE]LL.*BI[CK]")]

# %%
df.narr1.str.contains("PUNCH.*WALL").value_counts()
# Out:
# False    355955
# True       1772
# Name: narr1, dtype: int64

# %%
df_wall_punch = df[df['narr1'].str.contains("PUNCH.*WALL")]
df_wall_punch['sex'].value_counts()
# Out:
# Male      1348
# Female     424
# Name: sex, dtype: int64

# %% [markdown]
# ## Graph the gender distribution of wall-punching.

# %%
df_wall_punch = df[df['narr1'].str.contains("PUNCH.*WALL")]
df_wall_punch['sex'].value_counts().plot(kind = 'barh')

# %% [markdown]
# ## Find the average age of a wall-puncher.
#
# Graph the distribution of the ages, too.

# %%
df.columns
# Out:
# Index(['CPSC Case #', 'trmt_date', 'psu', 'weight', 'stratum', 'age', 'sex',
#        'race', 'race_other', 'diag', 'diag_other', 'body_part', 'disposition',
#        'location', 'fmv', 'prod1', 'prod2', 'narr1', 'narr2'],
#       dtype='object')

# %%
import statistics
df_wall_punch['age'].mean()
# Out:
# 24.303611738148984

# %% [markdown]
# # Which months are the most popular for wall punching?
#
# The month is hidden inside of the `trmt_date` column - you'll need to extract it. To check, January should have 27109 cases.

# %%
df_wall_punch['trmt_date'].str.extract('(\d\d)').value_counts().sort_values(ascending = False).head(3)
#September
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.
# 09    175
# 06    170
# 10    162
# Name: trmt_date, dtype: int64

# %% [markdown]
# ## Graph the amount of wall punching in each month
#
# Having numbers on the x axis (1-12) is fine.

# %%
df_wall_punch['trmt_date'].str.extract('(\d\d)').value_counts().sort_index(ascending = True).plot(kind = 'barh')
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Sort the graph so that the months are in order from Jan-Dec (or 01-12)

# %%
#done above

# %% [markdown]
# ## What month is most common for air conditioner-related injuries?
#
# Use the product code, which you can find in `2017ComparabilityTable.pdf` or `categories-cleaned.txt`.

# %%
df_air = df[df['narr1'].str.contains("AIR.*CONDITION")]
df_air
# Out:
#         CPSC Case #   trmt_date  psu   weight stratum  age     sex  race  \
# 1917      150902259  08/30/2015   58  15.7762       V    9    Male     0
# 1940      150446654  04/22/2015   33  15.0591       V   41    Male     1
# 3464      150451830  04/19/2015   53  15.0591       V   33  Female     1
# 3795      150717896  07/05/2015    7  83.2157       S   49  Female     0
# 6958      151143964  11/13/2015   51  74.8813       L   18  Female     2
# 8569      151059865  10/21/2015   95  16.5650       V   53    Male     1
# 11746     150703973  06/22/2015   68  97.9239       M   61    Male     1
# 11867     151115868  10/14/2015   54  49.2646       M   20  Female     1
# 12845     150726308  07/05/2015   89  74.8813       L   28    Male     1
# 14096     150728689  07/09/2015   38  15.7762       V    2  Female     0
# 14597     150852426  08/18/2015   31   5.6748       C   11    Male     2
# 17423     150718519  06/26/2015   29  83.2157       S   10    Male     1
# 17818     150920271  08/19/2015   54  49.2646       M   24  Female     1
# 21610     160209172  11/11/2015   23  16.5650       V   65    Male     0
# 22439     151032569  09/15/2015  101  97.9239       M   58    Male     0
# 23012     150962475  08/18/2015   77  15.7762       V   46    Male     0
# 26071     150114332  01/04/2015   17  15.0591       V   87    Male     0
# 26224     150149537  01/12/2015   57  15.0591       V   18    Male     2
# 27805     150137700  01/14/2015   64  15.0591       V   29    Male     1
# 28161     150528168  05/05/2015   64  15.0591       V   51    Male     1
# 29297     150253767  02/22/2015   64  15.7762       V   46    Male     2
# 31238     150926949  07/23/2015    8   5.6748       C    7  Female     2
# 33217     150913939  08/18/2015   51  74.8813       L   34    Male     2
# 34153     151037550  10/07/2015   50  74.8813       L   54    Male     0
# 34543     150548436  05/19/2015   51  74.8813       L   43    Male     1
# 35667     151108158  11/01/2015   94  85.7374       S   42  Female     0
# 35695     150759955  07/29/2015   96  83.2157       S    6    Male     0
# 36800     150814538  07/19/2015   21  15.7762       V   18  Female     0
# 39046     160150755  10/06/2015   23  16.5650       V   85  Female     0
# 41535     151008429  09/30/2015   48  83.2157       S   50    Male     0
# ...             ...         ...  ...      ...     ...  ...     ...   ...
# 323024    151103012  10/29/2015   21  16.5650       V   52    Male     0
# 323450    151003285  09/30/2015   21  15.7762       V   72    Male     0
# 323682    151052732  10/13/2015   50  74.8813       L   38    Male     0
# 327272    150907887  08/13/2015    3  74.8813       L   28    Male     0
# 327302    150534926  05/14/2015   21  15.0591       V   54  Female     0
# 328633    150968313  09/18/2015    5  37.6645       L   34    Male     1
# 329080    150501189  04/29/2015   21  15.0591       V   34    Male     0
# 330405    151125889  10/19/2015   54  49.2646       M   71    Male     1
# 332042    150625303  06/06/2015   95  15.7762       V   77    Male     1
# 333644    150641309  05/22/2015   23  15.0591       V   83  Female     0
# 335232    150824859  08/04/2015   42  74.8813       L   27    Male     1
# 335308    150953176  09/06/2015   68  97.9239       M   35  Female     1
# 336589    150658502  06/23/2015   95  15.7762       V   34    Male     1
# 338473    150124677  01/01/2015   57  15.0591       V   31  Female     2
# 342954    150646388  06/15/2015   21  15.7762       V   42    Male     0
# 343390    150612797  05/04/2015    3  74.8813       L   68  Female     0
# 343758    151202204  11/28/2015   62  85.7374       S   84    Male     1
# 343759    151229756  04/22/2015   23  15.0591       V   33    Male     0
# 346262    150746944  07/18/2015   95  15.7762       V   36  Female     1
# 346772    150730942  06/24/2015   16  97.9239       M   54    Male     1
# 347086    150623422  05/18/2015   16  97.9239       M   40    Male     1
# 349713    151057957  10/03/2015   54  49.2646       M   17  Female     1
# 350293    151015748  10/05/2015   89  74.8813       L   29    Male     1
# 351007    150802785  07/29/2015   32   5.6748       C    4    Male     0
# 351992    150935063  07/04/2015   34  15.7762       V   28    Male     2
# 353498    150637989  06/10/2015   79  83.2157       S   37    Male     1
# 354044    150758936  07/23/2015   64  15.7762       V   37  Female     1
# 354897    150926982  09/07/2015    8   5.6748       C    7  Female     3
# 355020    150652123  06/18/2015   34  15.7762       V   16    Male     2
# 357567    150639298  06/11/2015   33  15.7762       V   41  Female     1
#
#           race_other  diag       diag_other  body_part  disposition  location  \
# 1917             NaN    59              NaN         35            1         1
# 1940             NaN    54              NaN         83            1         1
# 3464             NaN    71    SHOULDER PAIN         30            1         1
# 3795             NaN    59              NaN         88            1         1
# 6958             NaN    71         HEADACHE         75            1         0
# 8569             NaN    64              NaN         79            1         0
# 11746            NaN    67              NaN         85            1         1
# 11867            NaN    53              NaN         83            1         1
# 12845            NaN    57              NaN         31            1         1
# 14096            NaN    59              NaN         76            1         1
# 14597            NaN    59              NaN         75            1         0
# 17423            NaN    59              NaN         35            1         1
# 17818            NaN    64              NaN         79            1         1
# 21610            NaN    64              NaN         35            1         1
# 22439            NaN    64              NaN         35            1         0
# 23012            NaN    59              NaN         92            1         0
# 26071            NaN    59              NaN         92            1         1
# 26224            NaN    57              NaN         82            1         0
# 27805            NaN    59              NaN         75            1         1
# 28161            NaN    67              NaN         85            8         0
# 29297            NaN    64              NaN         79            1         0
# 31238            NaN    60              NaN         88            1         1
# 33217            NaN    71             PAIN         30            1         0
# 34153            NaN    48              NaN         82            1         0
# 34543            NaN    57              NaN         92            1         0
# 35667            NaN    53              NaN         83            1         1
# 35695            NaN    59              NaN         92            1         0
# 36800            NaN    53              NaN         77            1         1
# 39046            NaN    57              NaN         81            4         1
# 41535            NaN    71        NECK PAIN         89            6         0
# ...              ...   ...              ...        ...          ...       ...
# 323024           NaN    71       HERNIATION         79            1         1
# 323450           NaN    57              NaN         79            4         1
# 323682           NaN    54              NaN         82            1         0
# 327272           NaN    59              NaN         80            1         0
# 327302           NaN    54              NaN         92            1         1
# 328633           NaN    67              NaN         85            1         1
# 329080           NaN    71    TENOSYNOVITIS         92            1         1
# 330405           NaN    71  COSTOCHONDRITIS         31            1         1
# 332042           NaN    53              NaN         83            1         1
# 333644           NaN    71             PAIN         31            1         0
# 335232           NaN    57              NaN         83            1         0
# 335308           NaN    64              NaN         92            1         1
# 336589           NaN    64              NaN         79            1         1
# 338473           NaN    71        NECK PAIN         89            1         0
# 342954           NaN    71             PAIN         30            1         1
# 343390           NaN    53              NaN         83            1         0
# 343758           NaN    64              NaN         79            1         1
# 343759           NaN    55              NaN         30            1         0
# 346262           NaN    59              NaN         34            1         1
# 346772           NaN    71             PAIN         79            1         1
# 347086           NaN    49              NaN         77            1         1
# 349713           NaN    59              NaN         83            1         1
# 350293           NaN    50              NaN         92            1         1
# 351007           NaN    59              NaN         76            1         1
# 351992           NaN    53              NaN         82            1         0
# 353498           NaN    54              NaN         92            1         0
# 354044           NaN    71             PAIN         31            1         0
# 354897  MULTI-RACIAL    63              NaN         31            1         0
# 355020           NaN    59              NaN         93            1         1
# 357567           NaN    71             PAIN         83            6         0
#
#         fmv prod1 prod2                                              narr1  \
# 1917      0   381   NaN                  9 YOM HIT KNEE ON AIR CONDITIONER
# 1940      0   381   NaN  41 YOM DROPPED AIR CONDITIONER ON L FOOT AT HO...
# 3464      0   381   NaN  33YOF-SHOULDER & ANKLE PAIN-FELL WHILE CARRYIN...
# 3795      0   381   NaN  49 Y O F LIP LACERATION SHE TRIPPED AND STRUCK...
# 6958      0   381   NaN  18 YO F C/O FRONTAL HEADACHE S/P HITTING HEAD ...
# 8569      0   381   NaN  LUMBAR STR.  53YOM STRAINED LOWER BACK MOVING ...
# 11746     0   381   NaN  61 YOM TRIED TAKING OFF THE COVER OF AIR CONDI...
# 11867     0   381   NaN  20YOF DROPPED AIR CONDITIONER ON RT FOOT. PAIN...
# 12845     0   381   NaN  28 YO M PT WAS WORKING ON HIS AIR CONDITIONER ...
# 14096     0   381   NaN  2YR OLD FEMALE FELL INTO AIRCONDITIONER CORNER...
# 14597     0   381   NaN  11 YO MALE RUNNING AND HIT HEAD ON AN AIR COND...
# 17423     0   381   NaN  10YOM RUNNING, HIT AN AIR CONDITIONER A ND CUT...
# 17818     0   381   NaN  24YOF LIFTING AIR CONDITIONER, HEARD 'SOMETHIN...
# 21610     0  1842   381  65 YO MALE HURT CARRYING AN AIR CONDITIONER UP...
# 22439     0   381   NaN  58YOM COMPLAINED OF LEFT KNEE PAIN AFTER LIFTI...
# 23012     0   381   NaN  46YOM SUST LAC TO FINGER WHEN HE WAS WORKING O...
# 26071     0   381   NaN        87YOM LAC FINGER- FELL ONTO AIR CONDITIONER
# 26224     0   381   NaN  18 YOM DX HAND FX - S/P AIR CONDITIONER FELL O...
# 27805     0   381   NaN  29YOM PT COMPLAINING OF HITTING HEAD ON AIR CO...
# 28161     0   381   NaN  51YOM REPORTS WITH ELECTRICAL SHOCK WHILE WORK...
# 29297     0   381   NaN  46YOM WITH LOW BACK STRAIN AFTER LIFTING AN AI...
# 31238     0   381   NaN  7YOF FELL AND TOOTH CAUGHT ON AIR CONDITIONER ...
# 33217     0   381  1842  34 YO M AT APPROX 3PM YESTERDAY HELPING FRIEND...
# 34153     0   381   NaN  54 YOM SCALD BURN HANDS, REPAIRING AN AIR COND...
# 34543     0   381   NaN  43 YO M, C/O B/L HAND PAIN 2 DAYS WAS MOVNING ...
# 35667     0   381   NaN   42YOF AT HOME DROPPED AIR CONDITIONER ON L FOOT/
# 35695     0   381   NaN           6 YOM CUT FINGER ON AIR CONDITIONER UNIT
# 36800     0   381   NaN  18YF TURNED ON AN AIR-CONDITIONER THAT HAD SAW...
# 39046     0   381  1807  85-YOF GETTING UP TO ADJUST AIR CONDITIONER, F...
# 41535     0   381   NaN  50 YOM - NECK PAIN - PT LIFTED AIR CONDITIONER...
# ...     ...   ...   ...                                                ...
# 323024    0   381   NaN  52YM WAS LIFTING AN AIR-CONDITIONER 3D AGO&DEV...
# 323450    0   381  1884  72YM ATTEMPTING TO TURN OFF THE AIR-CONDITIONE...
# 323682    0   381   NaN  38 YOM CRUSH INJURY HAND, REPORTS AN AIR CONDI...
# 327272    0   381   NaN  28YOM WAS WORKING ON AIR CONDITIONER WHEN THE ...
# 327302    0   381  1894  54YF A WINDOW SLAMMED ON HER FINGERS YTD WHILE...
# 328633    0   381   NaN  34 YOM WAS SHOCKED BY A 480V AIR CONDITIONING ...
# 329080    0   381   NaN  34YM C/O LT MIDDLE FINGER PAIN/SWELLING BEGAN ...
# 330405    0   381   NaN  71YOM PICKED UP AIR CONDITIONER, C/O LT SIDE R...
# 332042    0   381   NaN  RT FOOT CONT.  77YOM DROPPED AN AIR CONDITIONE...
# 333644    0   381   NaN  83-YOF TRIPPED OVER WALKER, STRUCK LEFT RIBS O...
# 335232    0   381   NaN  27YOM PAIN TO R FOOT WHEN A AIR CONDITIONING U...
# 335308    0   604   381  35YOF SPRAINED FINGER PINCHED BETWEEN WOODEN C...
# 336589    0   381   NaN  LUMBAR STRAIN. 34 YOM STRAINED HIS LOWER BACK ...
# 338473    0   381   NaN  31 YOF DX RT NECK/SHOULDER PAIN - PT LIFTING H...
# 342954    0   381  1894  42YM WAS LIFTING A HEAVY AIR-CONDITIONER INTO ...
# 343390    0  1135   NaN  68YOF BOTTLE OF HAIR CONDITIONER FELL FROM 4 F...
# 343758    0   381  1894  84 YO WM PULLING AN AIR CONDITIONER OUT OF A W...
# 343759    0   381   NaN  33 YO MALE HURT MOVING AN AIR CONDITIONER  AT ...
# 346262    0   381  1894  WRIST LAC.  36YOF INSTALLING AIR CONDITIONER A...
# 346772    0   381   NaN  54 YOM WAS LIFTING AN AIR CONDITIONER AND INJU...
# 347086    0   381  1894  40 YOM STATES WAS PUTTING AIR CONDITIONER INTO...
# 349713    0   381   NaN  17YOF STEPPED ON PLASTIC AIR CONDITIONER COVER...
# 350293    0   381   NaN  29 YO M PT WAS WORKING ON HIS AIR CONDITIONER ...
# 351007    0   381   NaN  4 YOM FELL AND HIT HIS FOREHEAD OFF CORNER OF ...
# 351992    0   381   NaN  28 YM WAS CARRYING AN AIR CONDITIONER AND SLIP...
# 353498    0   381   NaN  37YOM DROPPED AIR CONDITIONER ON FINGER   CRUS...
# 354044    0   381   NaN  37YOF WITH BACK PAIN AFTER HELPING LIFT AN AIR...
# 354897    0   381   NaN  7YOF PUSHED INTO AN AIR CONDITIONING UNIT; PUN...
# 355020    0   381   NaN  16YM, INJURED WHEN ACCIDENTALLY KICKED AIR CON...
# 357567    0   381   NaN  41 YOF DROPPED AIR CONDITIONER ON L FOOT D :  ...
#
#                                                     narr2
# 1917                                       DX  LACERATION
# 1940                                                  NaN
# 3464                                                   ME
# 3795                                 PLAYING WITH HER DOG
# 6958                                      DAY DX HEADACHE
# 8569                                                  NaN
# 11746   ENT THROUGH BODY. DX MILD RHABDOMYOLYSIS, ELEC...
# 11867                            TOE   DX: FOOT CONTUSION
# 12845   T LANDING ON THE GROUND,HURTING UPPER BACK,.DX...
# 14096                                                 NaN
# 14597                                                TION
# 17423                                    DX.   LAC. KNEE.
# 17818                                  DX;  LUMBAR STRAIN
# 21610                                                 NaN
# 22439                                    LEFT KNEE SPRAIN
# 23012       AND ACCIDENTALLY CUT FINGER ON A METAL PIECE*
# 26071                                                 NaN
# 26224                                                 NaN
# 27805                      ACERATION DX SCALP LACERATION#
# 28161                                  DX ELECTRIC SHOCK*
# 29297                                          DX STRAIN*
# 31238                                               NJURY
# 33217   GOING UP STAIRS FELL BACKWARDS DX RIB SHOULDER...
# 34153                 D FROM INSIDE LEAKED OUT ONTO HANDS
# 34543        T FELL ON HIS FINGERS DX HAND PAIN FINGER FX
# 35667                                 DX L FOOT CONTUSION
# 35695                              DX:  FINGER LACERATION
# 36800                                     YE>>CORNEAL ABR
# 39046   R.  DX:  CLOSED DISPLACED COMMINUTED FX OF SHA...
# 41535   OF NECK, ARM AND LEG PAIN. NO MENTION OF BEING...
# ...                                                   ...
# 323024                     TOCKS>>L-SPINE DISC HERNIATION
# 323450               LANCE FALLING AGAINST A WALL>>HIP FX
# 323682                                          1 DAY PTA
# 327272                               DX: LAC RT UPPER ARM
# 327302              ER IN HER WINDOW>>FINGER CURHING INJ.
# 328633  DX:  ELECTROCUTION & NONFATAL EFFECTS OF ELECT...
# 329080                          UNIT>>FLEXOR TENSYNOVITIS
# 330405                                              RITIS
# 332042                                                NaN
# 333644                                          RIB PAIN.
# 335232            PRIOR. - DEFORMITY NOTED. / BROKEN FOOT
# 335308                                             T HOME
# 336589                                                 R.
# 338473                                         MONTH AGO.
# 342954                                    >>SHOULDER PAIN
# 343390                                 DX: FOOT CONTUSION
# 343758                                LUMBAR SPINE STRAIN
# 343759                           SHOULDER DISLOCATION   B
# 346262                                                NaN
# 346772                                 DX LOWER BACK PAIN
# 347086  HED IN EYES WITH ***    DX CHEMICAL EXPOSURE T...
# 349713                                                LAC
# 350293     T IN AND CUT IT. DX AMPUTATION RT INDEX FINGER
# 351007                                  REHEAD LACERATION
# 351992                            HAND. DX HAND CONTUSION
# 353498                                                NaN
# 354044                                           DX PAIN*
# 354897                                                NaN
# 355020                                                NaN
# 357567                                                NaN
#
# [265 rows x 19 columns]

# %%
df_air['trmt_date'].str.extract('(\d\d)').value_counts().head(1)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.
# 07    36
# Name: trmt_date, dtype: int64

# %%
#so July is the most common

# %% [markdown]
# ## Find what else people punched using the prod1 and prod2 columns.
#
# Look at the top 10 for each separately.

# %%
df['prod1'] = df.prod1.str.pad(4, fillchar = '0')
df['prod2'] = df.prod2.str.pad(4, fillchar = '0')
df_all_punch = df[df['narr1'].str.contains('PUNCH')]
df_all_punch['prod1'].value_counts(ascending = False).head(10)
#df_all_punch['prod1'].value_counts().head(10)
# Out:
# 1884    1796
# 1894     566
# 1893     244
# 1207     159
# 4004     122
# 0276      74
# 4057      53
# 1892      48
# 1726      42
# 1807      41
# Name: prod1, dtype: int64

# %%
df_all_punch['prod2'].value_counts(ascending = False).head(10)
# Out:
# 1884    31
# 1893    13
# 1807     7
# 1207     7
# 4056     6
# 1892     6
# 0604     4
# 1865     4
# 0676     3
# 1819     3
# Name: prod2, dtype: int64

# %% [markdown]
# ## Uh, they're the same!

# %% [markdown]
# The order of `prod1` and `prod2` don't actually matter!
#
# > When only one product is associated with an injury, place the product code for that product in the space allocated for "First Product Code" and fill in the "Second Product Code" spaces with 4 zeros (0000).
# When two products are associated with an injury, either product may be coded as the first product and the other as the second product.
# >
# > Example: An 11-year old boy riding a bicycle ran into a swing. Code: Product 1 = 5040 (bicycle) and Product 2 = 3246 (swings) or
# >
# > Code: Product 1 = 3246 (swings) and Product 2 = 5040 (bicycle)
#
# ## Okay, okay, there’s no difference between prod1 and prod2, so you should add their frequencies together for an overall count!
#
# It's *almost* as easy as adding together the `value_counts()`.
#
# Take a look at the air conditioner question and the `.value_counts()` you just did, though, to see why combining them might not be that simple. **What is different about `prod1` and `prod2`?** You probably have to go all the way back up to where you read the file in to make them match.

# %%
df['prod2'].replace(np.nan, '0000', inplace = True)
df['prod1'].replace(np.nan, '0000', inplace = True)

# %%
prod1_value_counts = df_all_punch['prod1'].value_counts(ascending = False)

prod2_value_counts = df_all_punch['prod2'].value_counts(ascending = False)

# %%
prod1_value_counts.add(prod2_value_counts, fill_value=0).sort_values(ascending=False).head(10)
# Out:
# 1884    1827.0
# 1894     568.0
# 1893     257.0
# 1207     166.0
# 4004     124.0
# 0276      74.0
# 1892      54.0
# 4057      53.0
# 1807      48.0
# 4056      43.0
# dtype: float64

# %%
#(prod1_value_counts+prod2_value_counts).sort_values(ascending=False).head(10)

# %% [markdown]
# ## Turn that into a dataframe
#
# Use `.reset_index()` on the result to turn it into a dataframe. Rename your columns to be `product_code` and `injury_count`.

# %%
df_prods = prod1_value_counts.add(prod2_value_counts, fill_value=0).reset_index()
df_prods = df_prods.rename(columns={'index' : 'product_code', 0 : 'injury_count'})
df_prods.sort_values('injury_count', ascending = False)
# Out:
#     product_code  injury_count
# 89          1884        1827.0
# 95          1894         568.0
# 94          1893         257.0
# 52          1207         166.0
# 109         4004         124.0
# 8           0276          74.0
# 93          1892          54.0
# 117         4057          53.0
# 78          1807          48.0
# 116         4056          43.0
# 25          0604          42.0
# 75          1726          42.0
# 85          1865          41.0
# 23          0572          38.0
# 101         3257          20.0
# 87          1871          20.0
# 123         4074          18.0
# 30          0652          18.0
# 88          1878          14.0
# 66          1465          14.0
# 77          1738          13.0
# 11          0413          11.0
# 51          1205          11.0
# 16          0478          11.0
# 33          0679           9.0
# 90          1886           9.0
# 54          1240           9.0
# 125         4076           9.0
# 21          0557           8.0
# 91          1887           6.0
# ..           ...           ...
# 105         3274           1.0
# 99          3246           1.0
# 24          0576           1.0
# 26          0611           1.0
# 68          1616           1.0
# 65          1452           1.0
# 70          1645           1.0
# 64          1439           1.0
# 63          1347           1.0
# 73          1679           1.0
# 74          1715           1.0
# 61          1284           1.0
# 58          1270           1.0
# 56          1266           1.0
# 55          1261           1.0
# 50          1200           1.0
# 82          1841           1.0
# 49          1145           1.0
# 48          1144           1.0
# 46          1140           1.0
# 45          1137           1.0
# 44          1136           1.0
# 43          1127           1.0
# 40          0893           1.0
# 38          0814           1.0
# 36          0702           1.0
# 96          1895           1.0
# 98          3235           1.0
# 67          1602           1.0
# 0           0115           1.0
#
# [132 rows x 2 columns]

# %% [markdown]
# ## Fix the product codes
#
# Uh, wait, look at those product codes. "102" shouldn't be possible, it should be `0102` - this actually doesn't have to do with coding, it has to do with *the data doesn't match the codebook*.
#
# ### Add zeroes to the left of the product code until it is 4 characters long

# %%
#They all have 4 digits.

# %% [markdown]
# ## Get meaningful names for "product code"
#
# Join with `categories-cleaned.txt` to turn the codes into actual words. **When you read in `categories-cleaned.txt`, make sure it has 803 rows and 2 columns.**

# %%
df_categories = pd.read_csv('categories-cleaned.txt', header = None, names = ["product_code", "description"], dtype= {'product_code': str})
df_categories.head()
# Out:
#   product_code                              description
# 0         0102                 Wringer washing machines
# 1         0106  Electric clothes dryers without washers
# 2         0107       Gas clothes dryers without washers
# 3         0110                    Electric heating pads
# 4         0112           Sewing machines or accessories

# %%
df_categories.shape
# Out:
# (803, 2)

# %% [markdown]
# ### Confirm that it worked by seeing if product code '0102' gives you 'Wringer washing machines"

# %%
df_categories.head()
# Out:
#   product_code                              description
# 0         0102                 Wringer washing machines
# 1         0106  Electric clothes dryers without washers
# 2         0107       Gas clothes dryers without washers
# 3         0110                    Electric heating pads
# 4         0112           Sewing machines or accessories

# %%
combined_df = df_prods.merge(df_categories, left_on = 'product_code', right_on = 'product_code')
combined_df.head()
# Out:
#   product_code  injury_count  \
# 0         0115           1.0
# 1         0136           1.0
# 2         0137           1.0
# 3         0138           1.0
# 4         0140           1.0
#
#                                          description
# 0                                    Vacuum cleaners
# 1                                 Drinking fountains
# 2  Automatic doors or door openers (excluding gar...
# 3             Automatic garage doors or door openers
# 4           Washing machines, other or not specified

# %% [markdown]
# ## Graph the top 10 most popular products for injuries

# %%
graph = combined_df.sort_values('injury_count', ascending = False).head(10)

graph.head(10)
# Out:
#     product_code  injury_count  \
# 89          1884        1827.0
# 95          1894         568.0
# 94          1893         257.0
# 52          1207         166.0
# 109         4004         124.0
# 8           0276          74.0
# 93          1892          54.0
# 117         4057          53.0
# 78          1807          48.0
# 116         4056          43.0
#
#                                            description
# 89   Ceilings and walls (interior part of completed...
# 95   Windows and window glass, other than storm win...
# 94                       Doors, other or not specified
# 52             Boxing (activity, apparel or equipment)
# 109  Mirrors or mirror glass (excluding lighted mak...
# 8                                        Refrigerators
# 93              Glass doors or doors with glass panels
# 117  Tables, not elsewhere classified (excl. baby c...
# 78                        Floors or flooring materials
# 116  Cabinets, racks, room dividers and shelves, no...

# %%
graph.head(10).plot(kind = 'barh', x = 'product_code', y = 'injury_count')
